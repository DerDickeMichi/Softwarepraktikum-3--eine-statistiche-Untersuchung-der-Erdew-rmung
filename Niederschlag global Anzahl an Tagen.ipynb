# %%
import pandas as pd
from meteostat import Daily, Point
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Definiere den Ort für New York
new_york = Point(40.7128, -74.0060)

# Definiere den Zeitraum von 1950 bis heute
start = pd.to_datetime('1950-01-01')
end = pd.to_datetime('today')

# Lese die täglichen Daten für New York
data = Daily(new_york, start, end)
data = data.fetch()

# Überprüfe, ob Daten verfügbar sind
if data.empty:
    print("Keine Daten für den angegebenen Zeitraum verfügbar.")
else:
    # Finde Tage mit mehr als 10 mm Niederschlag
    data['heavy_rain'] = data['prcp'] > 10

    # Zähle die Anzahl der Tage pro Jahr
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Berechne einen gleitenden Durchschnitt (z.B. über 5 Jahre)
    heavy_rain_days_per_year_ma = heavy_rain_days_per_year.rolling(window=5).mean()

    # Berechne das Mean Squared Error (MSE)
    mse = mean_squared_error(heavy_rain_days_per_year[4:], heavy_rain_days_per_year_ma[4:])
    print(f'Mean Squared Error (MSE) für 5-jähriger gleitender Durchschnitt: {mse:.2f}')

    # Vorbereitung der Daten für lineare Regression
    years = heavy_rain_days_per_year.index.year.values.reshape(-1, 1)
    values = heavy_rain_days_per_year.values

    # Lineares Regressionsmodell erstellen und anpassen
    model = LinearRegression()
    model.fit(years, values)

    # Vorhersagen für die Regression
    trend_line = model.predict(years)

    # Plot der Anzahl der schweren Regentage pro Jahr mit Trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year, marker='o', linestyle='-', label='Anzahl Tage >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year_ma, linestyle='--', label='5-Jahre gleitender Durchschnitt')
    plt.plot(heavy_rain_days_per_year.index.year, trend_line, linestyle='-', color='red', label='Lineare Regression')
    plt.title('Anzahl der Tage mit >10 mm Regen in New York pro Jahr (1950 bis heute)')
    plt.xlabel('Jahr')
    plt.ylabel('Anzahl der Tage')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Mean Squared Error (MSE) für 5-jähriger gleitender Durchschnitt: 44.42
# FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.

# %%
import pandas as pd
from meteostat import Daily, Point
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Definiere den Ort für Lima
lima = Point(-12.0464, -77.0428)

# Definiere den Zeitraum von 1950 bis heute
start = pd.to_datetime('1950-01-01')
end = pd.to_datetime('today')

# Lese die täglichen Daten für Lima
data = Daily(lima, start, end)
data = data.fetch()

# Überprüfe, ob Daten verfügbar sind
if data.empty:
    print("Keine Daten für den angegebenen Zeitraum verfügbar.")
else:
    # Finde Tage mit mehr als 10 mm Niederschlag
    data['heavy_rain'] = data['prcp'] > 10

    # Zähle die Anzahl der Tage pro Jahr
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Berechne einen gleitenden Durchschnitt (z.B. über 5 Jahre)
    heavy_rain_days_per_year_ma = heavy_rain_days_per_year.rolling(window=5).mean()

    # Berechne das Mean Squared Error (MSE)
    mse = mean_squared_error(heavy_rain_days_per_year[4:], heavy_rain_days_per_year_ma[4:])
    print(f'Mean Squared Error (MSE) für 5-jähriger gleitender Durchschnitt: {mse:.2f}')

    # Vorbereitung der Daten für lineare Regression
    years = heavy_rain_days_per_year.index.year.values.reshape(-1, 1)
    values = heavy_rain_days_per_year.values

    # Lineares Regressionsmodell erstellen und anpassen
    model = LinearRegression()
    model.fit(years, values)

    # Vorhersagen für die Regression
    trend_line = model.predict(years)

    # Plot der Anzahl der schweren Regentage pro Jahr mit Trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year, marker='o', linestyle='-', label='Anzahl Tage >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year_ma, linestyle='--', label='5-Jahre gleitender Durchschnitt')
    plt.plot(heavy_rain_days_per_year.index.year, trend_line, linestyle='-', color='red', label='Lineare Regression')
    plt.title('Anzahl der Tage mit >10 mm Regen in Lima pro Jahr (1950 bis heute)')
    plt.xlabel('Jahr')
    plt.ylabel('Anzahl der Tage')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
# Mean Squared Error (MSE) für 5-jähriger gleitender Durchschnitt: 0.43
# FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.

# %%
import pandas as pd
from meteostat import Daily, Point
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Definiere den Ort für Moskau
moskau = Point(55.7558, 37.6173)

# Definiere den Zeitraum von 1950 bis heute
start = pd.to_datetime('1950-01-01')
end = pd.to_datetime('today')

# Lese die täglichen Daten für Moskau
data = Daily(moskau, start, end)
data = data.fetch()

# Überprüfe, ob Daten verfügbar sind
if data.empty:
    print("Keine Daten für Moskau verfügbar.")
else:
    # Finde Tage mit mehr als 10 mm Niederschlag
    data['heavy_rain'] = data['prcp'] > 10

    # Zähle die Anzahl der Tage pro Jahr
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Berechne einen gleitenden Durchschnitt (z.B. über 5 Jahre)
    heavy_rain_days_per_year_ma = heavy_rain_days_per_year.rolling(window=5).mean()

    # Berechne das Mean Squared Error (MSE)
    mse = mean_squared_error(heavy_rain_days_per_year[4:], heavy_rain_days_per_year_ma[4:])
    print(f'Mean Squared Error (MSE) für Moskau: {mse:.2f}')

    # Vorbereitung der Daten für lineare Regression
    years = heavy_rain_days_per_year.index.year.values.reshape(-1, 1)
    values = heavy_rain_days_per_year.values

    # Lineares Regressionsmodell erstellen und anpassen
    model = LinearRegression()
    model.fit(years, values)

    # Vorhersagen für die Regression
    trend_line = model.predict(years)

    # Plot der Anzahl der schweren Regentage pro Jahr mit Trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year, marker='o', linestyle='-', label='Anzahl Tage >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year_ma, linestyle='--', label='5-Jahre gleitender Durchschnitt')
    plt.plot(heavy_rain_days_per_year.index.year, trend_line, linestyle='-', color='red', label='Lineare Regression')
    plt.title('Anzahl der Tage mit >10 mm Regen in Moskau pro Jahr (1950 bis heute)')
    plt.xlabel('Jahr')
    plt.ylabel('Anzahl der Tage')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()

# Für Buenos Aires
buenos_aires = Point(-34.6037, -58.3816)

# Lese die täglichen Daten für Buenos Aires
data = Daily(buenos_aires, start, end)
data = data.fetch()

# Überprüfe, ob Daten verfügbar sind
if data.empty:
    print("Keine Daten für Buenos Aires verfügbar.")
else:
    # Finde Tage mit mehr als 10 mm Niederschlag
    data['heavy_rain'] = data['prcp'] > 10

    # Zähle die Anzahl der Tage pro Jahr
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Berechne einen gleitenden Durchschnitt (z.B. über 5 Jahre)
    heavy_rain_days_per_year_ma = heavy_rain_days_per_year.rolling(window=5).mean()

    # Berechne das Mean Squared Error (MSE)
    mse = mean_squared_error(heavy_rain_days_per_year[4:], heavy_rain_days_per_year_ma[4:])
    print(f'Mean Squared Error (MSE) für Buenos Aires: {mse:.2f}')

    # Vorbereitung der Daten für lineare Regression
    years = heavy_rain_days_per_year.index.year.values.reshape(-1, 1)
    values = heavy_rain_days_per_year.values

    # Lineares Regressionsmodell erstellen und anpassen
    model = LinearRegression()
    model.fit(years, values)

    # Vorhersagen für die Regression
    trend_line = model.predict(years)

    # Plot der Anzahl der schweren Regentage pro Jahr mit Trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year, marker='o', linestyle='-', label='Anzahl Tage >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year_ma, linestyle='--', label='5-Jahre gleitender Durchschnitt')
    plt.plot(heavy_rain_days_per_year.index.year, trend_line, linestyle='-', color='red', label='Lineare Regression')
    plt.title('Anzahl der Tage mit >10 mm Regen in Buenos Aires pro Jahr (1950 bis heute)')
    plt.xlabel('Jahr')
    plt.ylabel('Anzahl der Tage')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()

# Für Kapstadt (Cape Town)
cape_town = Point(-33.9249, 18.4241)

# Lese die täglichen Daten für Kapstadt
data = Daily(cape_town, start, end)
data = data.fetch()

# Überprüfe, ob Daten verfügbar sind
if data.empty:
    print("Keine Daten für Kapstadt verfügbar.")
else:
    # Finde Tage mit mehr als 10 mm Niederschlag
    data['heavy_rain'] = data['prcp'] > 10

    # Zähle die Anzahl der Tage pro Jahr
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Berechne einen gleitenden Durchschnitt (z.B. über 5 Jahre)
    heavy_rain_days_per_year_ma = heavy_rain_days_per_year.rolling(window=5).mean()

    # Berechne das Mean Squared Error (MSE)
    mse = mean_squared_error(heavy_rain_days_per_year[4:], heavy_rain_days_per_year_ma[4:])
    print(f'Mean Squared Error (MSE) für Kapstadt: {mse:.2f}')

    # Vorbereitung der Daten für lineare Regression
    years = heavy_rain_days_per_year.index.year.values.reshape(-1, 1)
    values = heavy_rain_days_per_year.values

    # Lineares Regressionsmodell erstellen und anpassen
    model = LinearRegression()
    model.fit(years, values)

    # Vorhersagen für die Regression
    trend_line = model.predict(years)

    # Plot der Anzahl der schweren Regentage pro Jahr mit Trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year, marker='o', linestyle='-', label='Anzahl Tage >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year_ma, linestyle='--', label='5-Jahre gleitender Durchschnitt')
    plt.plot(heavy_rain_days_per_year.index.year, trend_line, linestyle='-', color='red', label='Lineare Regression')
    plt.title('Anzahl der Tage mit >10 mm Regen in Kapstadt pro Jahr (1950 bis heute)')
    plt.xlabel('Jahr')
    plt.ylabel('Anzahl der Tage')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()

# Für Tokio
tokyo = Point(35.6762, 139.6503)

# Lese die täglichen Daten für Tokio
data = Daily(tokyo, start, end)
data = data.fetch()

# Überprüfe, ob Daten verfügbar sind
if data.empty:
    print("Keine Daten für Tokio verfügbar.")
else:
    # Finde Tage mit mehr als 10 mm Niederschlag
    data['heavy_rain'] = data['prcp'] > 10

    # Zähle die Anzahl der Tage pro Jahr
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Berechne einen gleitenden Durchschnitt (z.B. über 5 Jahre)
    heavy_rain_days_per_year_ma = heavy_rain_days_per_year.rolling(window=5).mean()

    # Berechne das Mean Squared Error (MSE)
    mse = mean_squared_error(heavy_rain_days_per_year[4:], heavy_rain_days_per_year_ma[4:])
    print(f'Mean Squared Error (MSE) für Tokio: {mse:.2f}')

    # Vorbereitung der Daten für lineare Regression
    years = heavy_rain_days_per_year.index.year.values.reshape(-1, 1)
    values = heavy_rain_days_per_year.values

    # Lineares Regressionsmodell erstellen und anpassen
    model = LinearRegression()
    model.fit(years, values)

    # Vorhersagen für die Regression
    trend_line = model.predict(years)

    # Plot der Anzahl der schweren Regentage pro Jahr mit Trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year, marker='o', linestyle='-', label='Anzahl Tage >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year, heavy_rain_days_per_year_ma, linestyle='--', label='5-Jahre gleitender Durchschnitt')
    plt.plot(heavy_rain_days_per_year.index.year, trend_line, linestyle='-', color='red', label='Lineare Regression')
    plt.title('Anzahl der Tage mit >10 mm Regen in Tokio pro Jahr (1950 bis heute)')
    plt.xlabel('Jahr')
    plt.ylabel('Anzahl der Tage')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Mean Squared Error (MSE) für Moskau: 17.47
# FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
# FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
# Mean Squared Error (MSE) für Buenos Aires: 52.38
# FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
# Mean Squared Error (MSE) für Kapstadt: 26.77
# FutureWarning: 'Y' is deprecated and will be removed in a future version, please use 'YE' instead.
# Mean Squared Error (MSE) für Tokio: 60.99
