# %%
# Import Meteostat library and dependencies
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# Set time period
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31)

# Create Point for Vancouver, BC
vancouver = Point(49.2497, -123.1193, 70)

# Get daily data for 2018
data = Daily(vancouver, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
from datetime import datetime

# Städte und deren geographische Koordinaten
cities = {
    'New York': {'lat': 40.7128, 'lon': -74.0060},
    'Tokyo': {'lat': 35.6762, 'lon': 139.6503},
    'Cape Town': {'lat': -33.9249, 'lon': 18.4241},
    'Buenos Aires': {'lat': -34.6037, 'lon': -58.3816},
    'Brasilia': {'lat': -15.7801, 'lon': -47.9292},
    'Moscow': {'lat': 55.7558, 'lon': 37.6173}
}

# Zeitraum: Beginnt mit dem frühestmöglichen Datum
start_date = datetime(1973, 1, 1)

# Erstellen Sie ein Diagramm
plt.figure(figsize=(10, 6))

# Daten für jede Stadt abfragen
for city, coords in cities.items():
    # Setzen des Punktes für die Stadt
    city_point = Point(coords['lat'], coords['lon'])

    # Abrufen der täglichen Wetterdaten (Niederschlag) ab dem frühestmöglichen Zeitpunkt
    data = Daily(city_point, start_date, datetime.today())
    data = data.fetch()

    # Berechnen der maximalen täglichen Niederschlagswerte
    max_precipitation = data['precip'].max()

    # Plotten der maximalen Niederschlagswerte
    plt.bar(city, max_precipitation, label=f'{city}: {max_precipitation:.2f} mm')

# Diagramm anpassen
plt.title("Maximale Niederschläge in verschiedenen Städten")
plt.ylabel("Maximaler Niederschlag (mm)")
plt.xticks(rotation=45)
plt.tight_layout()

# Diagramm anzeigen
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/Extremwetter/wetter/lib/python3.13/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'precip'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 32
#      29 data = data.fetch()
# ...

# %%
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
from datetime import datetime

# Städte und deren geographische Koordinaten
cities = {
    'New York': {'lat': 40.7128, 'lon': -74.0060},
    'Tokyo': {'lat': 35.6762, 'lon': 139.6503},
    'Cape Town': {'lat': -33.9249, 'lon': 18.4241},
    'Buenos Aires': {'lat': -34.6037, 'lon': -58.3816},
    'Brasilia': {'lat': -15.7801, 'lon': -47.9292},
    'Moscow': {'lat': 55.7558, 'lon': 37.6173}
}

# Zeitraum: Beginnt mit dem frühestmöglichen Datum
start_date = datetime(1973, 1, 1)

# Erstellen Sie ein Diagramm
plt.figure(figsize=(10, 6))

# Daten für jede Stadt abfragen
for city, coords in cities.items():
    # Setzen des Punktes für die Stadt
    city_point = Point(coords['lat'], coords['lon'])

    # Abrufen der täglichen Wetterdaten (Niederschlag) ab dem frühestmöglichen Zeitpunkt
    data = Daily(city_point, start_date, datetime.today())
    data = data.fetch()

    # Überprüfen, welche Spalten in den Daten vorhanden sind
    print(f"Spalten für {city}: {data.columns}")

    # Sicherstellen, dass die Niederschlagsdaten vorhanden sind
    if 'precip' in data.columns:
        # Berechnen der maximalen täglichen Niederschlagswerte
        max_precipitation = data['precip'].max()
    else:
        max_precipitation = 0  # Falls keine Niederschlagsdaten vorhanden sind

    # Plotten der maximalen Niederschlagswerte
    plt.bar(city, max_precipitation, label=f'{city}: {max_precipitation:.2f} mm')

# Diagramm anpassen
plt.title("Maximale Niederschläge in verschiedenen Städten")
plt.ylabel("Maximaler Niederschlag (mm)")
plt.xticks(rotation=45)
plt.tight_layout()

# Diagramm anzeigen
plt.legend()
plt.show()
# Out:
# Spalten für New York: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')
# ...
# Spalten für Tokyo: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')
# ...
# Spalten für Cape Town: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')
# ...
# Spalten für Buenos Aires: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')
# ...
# Spalten für Brasilia: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')
# ...
# Spalten für Moscow: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
from datetime import datetime

# Geographische Koordinaten von New York
nyc = Point(40.7128, -74.0060)

# Zeitraum: Beginnt mit dem frühestmöglichen Datum
start_date = datetime(1973, 1, 1)

# Abrufen der täglichen Wetterdaten (Niederschlag) ab dem frühestmöglichen Zeitpunkt
data = Daily(nyc, start_date, datetime.today())
data = data.fetch()

# Überprüfen der verfügbaren Spalten in den Daten
print("Verfügbare Spalten:", data.columns)

# Sicherstellen, dass Niederschlagsdaten vorhanden sind
if 'precip' in data.columns:
    # Berechnen der maximalen täglichen Niederschlagswerte
    max_precipitation = data['precip'].max()
    print(f"Maximaler Niederschlag in New York: {max_precipitation} mm")
else:
    print("Keine Niederschlagsdaten verfügbar!")

# Visualisierung der maximalen Niederschläge
plt.figure(figsize=(8, 5))
plt.bar("New York", max_precipitation, color='blue')

# Diagramm anpassen
plt.title("Maximaler Niederschlag in New York")
plt.ylabel("Maximaler Niederschlag (mm)")
plt.tight_layout()

# Diagramm anzeigen
plt.show()
# Out:
# Verfügbare Spalten: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')
# Keine Niederschlagsdaten verfügbar!

# %%
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
from datetime import datetime

# Geographische Koordinaten von Hamburg
hamburg = Point(53.5511, 9.9937)

# Zeitraum: Beginnt mit dem frühestmöglichen Datum
start_date = datetime(1973, 1, 1)

# Abrufen der täglichen Wetterdaten (Niederschlag) ab dem frühestmöglichen Zeitpunkt
data = Daily(hamburg, start_date, datetime.today())
data = data.fetch()

# Überprüfen der verfügbaren Spalten in den Daten
print("Verfügbare Spalten:", data.columns)

# Sicherstellen, dass Niederschlagsdaten vorhanden sind
if 'precip' in data.columns:
    # Berechnen der maximalen täglichen Niederschlagswerte
    max_precipitation = data['precip'].max()
    print(f"Maximaler Niederschlag in Hamburg: {max_precipitation} mm")
else:
    print("Keine Niederschlagsdaten verfügbar!")

# Visualisierung der maximalen Niederschläge
plt.figure(figsize=(8, 5))
plt.bar("Hamburg", max_precipitation, color='green')

# Diagramm anpassen
plt.title("Maximaler Niederschlag in Hamburg")
plt.ylabel("Maximaler Niederschlag (mm)")
plt.tight_layout()

# Diagramm anzeigen
plt.show()
# Out:
# ...
# Verfügbare Spalten: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')
# Keine Niederschlagsdaten verfügbar!

# %%
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
from datetime import datetime

# Geographische Koordinaten von Hamburg
hamburg = Point(53.5511, 9.9937)

# Zeitraum: Beginnt mit dem frühestmöglichen Datum
start_date = datetime(1973, 1, 1)

# Abrufen der täglichen Wetterdaten (Niederschlag) ab dem frühestmöglichen Zeitpunkt
data = Daily(hamburg, start_date, datetime.today())
data = data.fetch()

# Ausgabe der ersten Zeilen der abgerufenen Daten, um zu prüfen, was enthalten ist
print(data.head())  # Zeige die ersten Zeilen der Daten an

# Überprüfen der verfügbaren Spalten in den Daten
print("Verfügbare Spalten:", data.columns)

# Sicherstellen, dass Niederschlagsdaten vorhanden sind und den maximalen Wert berechnen
if 'precip' in data.columns:
    max_precipi
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun
# time
# 1973-01-01  -6.9  -9.2  -2.2   0.0   0.0    NaN   6.1  10.8  1028.9  354.0
# 1973-01-02  -3.3 -10.1   0.8   0.0   0.0    NaN   6.8  13.7  1029.5  228.0
# 1973-01-03   1.8  -1.9   3.0   0.2   0.0    NaN  11.9  25.2  1028.4    0.0
# 1973-01-04  -1.0  -1.4   1.8   0.0   0.0  287.0   6.8  14.4  1035.6    0.0
# 1973-01-05   2.9  -1.3   3.9   0.6   0.0  266.0   9.7  21.2  1038.0    0.0
# Verfügbare Spalten: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
from meteostat import Point, Daily
import pandas as pd
from datetime import datetime

# Geographische Koordinaten von Hamburg
hamburg = Point(53.5511, 9.9937)

# Zeitraum: Beginnt mit dem frühestmöglichen Datum
start_date = datetime(1973, 1, 1)

# Abrufen der täglichen Wetterdaten (Niederschlag) ab dem frühestmöglichen Zeitpunkt
data = Daily(hamburg, start_date, datetime.today())
data = data.fetch()

# Ausgabe der ersten Zeilen der abgerufenen Daten, um zu prüfen, was enthalten ist
print(data.head())  # Zeige die ersten Zeilen der Daten an

# Überprüfen der verfügbaren Spalten in den Daten
print("Verfügbare Spalten:", data.columns)

# Sicherstellen, dass Niederschlagsdaten vorhanden sind und den maximalen Wert berechnen
if 'precip' in data.columns:
    max_precipitation = data['precip'].max()
    print(f"Maximaler Niederschlag in Hamburg: {max_precipitation} mm")
else:
    print("Die Spalte 'precip' wurde nicht gefunden. Verfügbare Spalten:", data.columns)

# Wenn die Niederschlagsdaten vorhanden sind, visualisieren
if 'precip' in data.columns:
    plt.figure(figsize=(8, 5))
    plt.bar("Hamburg", max_precipitation, color='green')

    # Diagramm anpassen
    plt.title("Maximaler Niederschlag in Hamburg")
    plt.ylabel("Maximaler Niederschlag (mm)")
    plt.tight_layout()

    # Diagramm anzeigen
    plt.show()
else:
    print("Es wurden keine Niederschlagsdaten zum Visualisieren gefunden.")
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres   tsun
# time
# 1973-01-01  -6.9  -9.2  -2.2   0.0   0.0    NaN   6.1  10.8  1028.9  354.0
# 1973-01-02  -3.3 -10.1   0.8   0.0   0.0    NaN   6.8  13.7  1029.5  228.0
# 1973-01-03   1.8  -1.9   3.0   0.2   0.0    NaN  11.9  25.2  1028.4    0.0
# 1973-01-04  -1.0  -1.4   1.8   0.0   0.0  287.0   6.8  14.4  1035.6    0.0
# 1973-01-05   2.9  -1.3   3.9   0.6   0.0  266.0   9.7  21.2  1038.0    0.0
# Verfügbare Spalten: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')
# Die Spalte 'precip' wurde nicht gefunden. Verfügbare Spalten: Index(['tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wdir', 'wspd', 'wpgt', 'pres',
#        'tsun'],
#       dtype='object')
# Es wurden keine Niederschlagsdaten zum Visualisieren gefunden.

# %%
import pandas as pd
from meteostat import Daily, Point
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Definiere die geographischen Koordinaten der Städte
cities = {
    'New York': (40.7128, -74.0060),
    'Tokyo': (35.6762, 139.6503),
    'Cape Town': (-33.9249, 18.4241),
    'Buenos Aires': (-34.6037, -58.3816),
    'Brasília': (-15.7801, -47.9292),
    'Moscow': (55.7558, 37.6173)
}

# Definiere den Zeitraum von 1950 bis heute
start = pd.to_datetime('1950-01-01')
end = pd.to_datetime('today')

# Erstelle eine Figur für die Plots
plt.figure(figsize=(14, 7))

# Durchlaufe jede Stadt und berechne den Niederschlag
for city, coords in cities.items():
    # Definiere den Punkt für die Stadt
    city_point = Point(coords[0], coords[1])

    # Lese die täglichen Daten für die Stadt
    data = Daily(city_point, start, end)
    data = data.fetch()

    # Überprüfe, ob Daten verfügbar sind
    if data.empty:
        print(f"Keine Daten für {city} im angegebenen Zeitraum verfügbar.")
        continue

    # Finde Tage mit mehr als 10 mm Niederschlag
    data['heavy_rain'] = data['prcp'] > 10

    # Zähle die Anzahl der Tage pro Jahr
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Berechne die prozentuale jährliche Änderung
    percentage_change = heavy_rain_days_per_year.pct_change() * 100

    # Rollende Mittelwerte der prozentualen Änderungen
    percentage_change_ma = percentage_change.rolling(window=5).mean()
    percentage_change_ema = percentage_change.ewm(span=5).mean()
    weights = np.arange(1, 6)
    percentage_change_weighted = percentage_change.rolling(window=5).apply(
        lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
    )

    # Berechne das Mean Squared Error (MSE) für die Methoden
    mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
    mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
    mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])

    print(f'Mean Squared Error (MSE) für 5-Jahre gleitender Durchschnitt (prozentual) in {city}: {mse_ma:.2f}')
    print(f'Mean Squared Error (MSE) für den exponentiellen gleitenden Durchschnitt (prozentual) in {city}: {mse_ema:.2f}')
    print(f'Mean Squared Error (MSE) für den gewichteten Durchschnitt (prozentual) in {city}: {mse_weighted:.2f}')

    # Vorbereitung der Daten für lineare Regression
    years = heavy_rain_days_per_year.index.year.values[1:].reshape(-1, 1)  # Überspringe das erste Jahr wegen pct_change()
    values = percentage_change.values[1:]  # Überspringe den ersten Wert (NaN von pct_change())

    # Lineares Regressionsmodell erstellen und anpassen
    model = LinearRegression()
    model.fit(years, values)

    # Vorhersagen für die Regression
    trend_line = model.predict(years)

    # Berechne das Mean Squared Error (MSE) für das lineare Regressionsmodell
    mse_regression = mean_squared_error(values, trend_line)
    print(f'Mean Squared Error (MSE) für die lineare Regression (prozentual) in {city}: {mse_regression:.2f}')

    # Plot der prozentualen Änderung der schweren Regentage pro Jahr mit Trends
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change[1:], marker='o', linestyle='-',
             label=f'{city} - Prozentuale Änderung der Anzahl Tage >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ma[1:], linestyle='--',
             label=f'{city} - 5-Jahre gleitender Durchschnitt (SMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ema[1:], linestyle='-.',
             label=f'{city} - Exponentieller gleitender Durchschnitt (EMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_weighted[1:], linestyle=':',
             label=f'{city} - Gewichteter Durchschnitt')
    plt.plot(heavy_rain_days_per_year.index.year[1:], trend_line, linestyle='-', color='red',
             label=f'{city} - Lineare Regression')

# Diagramm anpassen
plt.title('Prozentuale Änderung der Tage mit >10 mm Regen in verschiedenen Städten (1950 bis heute)')
plt.xlabel('Jahr')
plt.ylabel('Prozentuale Änderung (%)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Diagramm anzeigen
plt.show()
# Out:
# Mean Squared Error (MSE) für 5-Jahre gleitender Durchschnitt (prozentual) in New York: 565.95
# Mean Squared Error (MSE) für den exponentiellen gleitenden Durchschnitt (prozentual) in New York: 408.00
# Mean Squared Error (MSE) für den gewichteten Durchschnitt (prozentual) in New York: 443.88
# Mean Squared Error (MSE) für die lineare Regression (prozentual) in New York: 654.23
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 57
#      52 percentage_change_weighted = percentage_change.rolling(window=5).apply(
#      53     lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
#      54 )
#      56 # Berechne das Mean Squared Error (MSE) für die Methoden
# ---> 57 mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
#      58 mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
# ...

# %%
import pandas as pd
from meteostat import Daily, Point
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Definiere die geographischen Koordinaten der Städte
cities = {
    'New York': (40.7128, -74.0060),
    'Tokyo': (35.6762, 139.6503),
    'Cape Town': (-33.9249, 18.4241),
    'Buenos Aires': (-34.6037, -58.3816),
    'Brasília': (-15.7801, -47.9292),
    'Moscow': (55.7558, 37.6173)
}

# Definiere den Zeitraum von 1950 bis heute
start = pd.to_datetime('1950-01-01')
end = pd.to_datetime('today')

# Erstelle eine Figur für die Plots
plt.figure(figsize=(14, 7))

# Durchlaufe jede Stadt und berechne den Niederschlag
for city, coords in cities.items():
    # Definiere den Punkt für die Stadt
    city_point = Point(coords[0], coords[1])

    # Lese die täglichen Daten für die Stadt
    data = Daily(city_point, start, end)
    data = data.fetch()

    # Überprüfe, ob Daten verfügbar sind
    if data.empty:
        print(f"Keine Daten für {city} im angegebenen Zeitraum verfügbar.")
        continue

    # Finde Tage mit mehr als 10 mm Niederschlag
    data['heavy_rain'] = data['prcp'] > 10

    # Zähle die Anzahl der Tage pro Jahr
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Berechne die prozentuale jährliche Änderung
    percentage_change = heavy_rain_days_per_year.pct_change() * 100

    # Rollende Mittelwerte der prozentualen Änderungen
    percentage_change_ma = percentage_change.rolling(window=5).mean()
    percentage_change_ema = percentage_change.ewm(span=5).mean()
    weights = np.arange(1, 6)
    percentage_change_weighted = percentage_change.rolling(window=5).apply(
        lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
    )

    # Entfernen von NaN-Werten aus den Arrays vor der MSE-Berechnung
    valid_indices = ~np.isnan(percentage_change[5:])
    valid_percentage_change = percentage_change[5:][valid_indices]
    valid_percentage_change_ma = percentage_change_ma[5:][valid_indices]
    valid_percentage_change_ema = percentage_change_ema[5:][valid_indices]
    valid_percentage_change_weighted = percentage_change_weighted[5:][valid_indices]

    # Berechne das Mean Squared Error (MSE) für die Methoden
    mse_ma = mean_squared_error(valid_percentage_change, valid_percentage_change_ma)
    mse_ema = mean_squared_error(valid_percentage_change, valid_percentage_change_ema)
    mse_weighted = mean_squared_error(valid_percentage_change, valid_percentage_change_weighted)

    print(f'Mean Squared Error (MSE) für 5-Jahre gleitender Durchschnitt (prozentual) in {city}: {mse_ma:.2f}')
    print(f'Mean Squared Error (MSE) für den exponentiellen gleitenden Durchschnitt (prozentual) in {city}: {mse_ema:.2f}')
    print(f'Mean Squared Error (MSE) für den gewichteten Durchschnitt (prozentual) in {city}: {mse_weighted:.2f}')

    # Vorbereitung der Daten für lineare Regression
    years = heavy_rain_days_per_year.index.year.values[1:].reshape(-1, 1)  # Überspringe das erste Jahr wegen pct_change()
    values = percentage_change.values[1:]  # Überspringe den ersten Wert (NaN von pct_change())

    # Entfernen von NaN-Werten vor der linearen Regression
    valid_years = years[~np.isnan(values)]
    valid_values = values[~np.isnan(values)]

    # Lineares Regressionsmodell erstellen und anpassen
    model = LinearRegression()
    model.fit(valid_years, valid_values)

    # Vorhersagen für die Regression
    trend_line = model.predict(valid_years)

    # Berechne das Mean Squared Error (MSE) für das lineare Regressionsmodell
    mse_regression = mean_squared_error(valid_values, trend_line)
    print(f'Mean Squared Error (MSE) für die lineare Regression (prozentual) in {city}: {mse_regression:.2f}')

    # Plot der prozentualen Änderung der schweren Regentage pro Jahr mit Trends
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change[1:], marker='o', linestyle='-',
             label=f'{city} - Prozentuale Änderung der Anzahl Tage >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ma[1:], linestyle='--',
             label=f'{city} - 5-Jahre gleitender Durchschnitt (SMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ema[1:], linestyle='-.',
             label=f'{city} - Exponentieller gleitender Durchschnitt (EMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_weighted[1:], linestyle=':',
             label=f'{city} - Gewichteter Durchschnitt')
    plt.plot(heavy_rain_days_per_year.index.year[1:], trend_line, linestyle='-', color='red',
             label=f'{city} - Lineare Regression')

# Diagramm anpassen
plt.title('Prozentuale Änderung der Tage mit >10 mm Regen in verschiedenen Städten (1950 bis heute)')
plt.xlabel('Jahr')
plt.ylabel('Prozentuale Änderung (%)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# Diagramm anzeigen
plt.show()
# Out:
# Mean Squared Error (MSE) für 5-Jahre gleitender Durchschnitt (prozentual) in New York: 565.95
# Mean Squared Error (MSE) für den exponentiellen gleitenden Durchschnitt (prozentual) in New York: 408.00
# Mean Squared Error (MSE) für den gewichteten Durchschnitt (prozentual) in New York: 443.88
# Mean Squared Error (MSE) für die lineare Regression (prozentual) in New York: 654.23
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 64
#      61 valid_percentage_change_weighted = percentage_change_weighted[5:][valid_indices]
#      63 # Berechne das Mean Squared Error (MSE) für die Methoden
# ---> 64 mse_ma = mean_squared_error(valid_percentage_change, valid_percentage_change_ma)
#      65 mse_ema = mean_squared_error(valid_percentage_change, valid_percentage_change_ema)
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt

# Set the location for New York City (latitude, longitude, altitude)
new_york = Point(40.7128, -74.0060, 10)

# Define the date range (e.g., last year)
start_date = '2023-01-01'
end_date = '2023-12-31'

# Fetch daily data from Meteostat
data = Daily(new_york, start_date, end_date)
data = data.fetch()

# Filter days with precipitation over 10 mm
high_precipitation_days = data[data['prcp'] > 10]

# Display the results
print(f"Days with precipitation > 10mm in New York between {start_date} and {end_date}:\n")
print(high_precipitation_days)

# Plot the high precipitation days
plt.figure(figsize=(10, 6))
high_precipitation_days['prcp'].plot(kind='bar', color='blue', alpha=0.7)
plt.title('Days with Precipitation > 10mm in New York')
plt.xlabel('Date')
plt.ylabel('Precipitation (mm)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 13
#      10 end_date = '2023-12-31'
#      12 # Fetch daily data from Meteostat
# ---> 13 data = Daily(new_york, start_date, end_date)
#      14 data = data.fetch()
#      16 # Filter days with precipitation over 10 mm
#
# File ~/Desktop/Extremwetter/wetter/lib/python3.13/site-packages/meteostat/interface/daily.py:98, in Daily.__init__(self, loc, start, end, model, flags)
#      88 def __init__(
#      89     self,
#      90     loc: Union[pd.DataFrame, Point, list, str],  # Station(s) or geo point
#    (...)
#      96
#      97     # Initialize time series
# ---> 98     self._init_time_series(loc, start, end, model, flags)
#
# File ~/Desktop/Extremwetter/wetter/lib/python3.13/site-packages/meteostat/interface/timeseries.py:156, in TimeSeries._init_time_series(self, loc, start, end, model, flags)
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt
from datetime import datetime

# Set the location for New York City (latitude, longitude, altitude)
new_york = Point(40.7128, -74.0060, 10)

# Define the date range (e.g., last year)
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 12, 31)

# Fetch daily data from Meteostat
data = Daily(new_york, start_date, end_date)
data = data.fetch()

# Check if the data is successfully fetched
if data.empty:
    print("No data available for the given date range and location.")
else:
    # Filter days with precipitation over 10 mm
    high_precipitation_days = data[data['prcp'] > 10]

    # Display the results
    print(f"Days with precipitation > 10mm in New York between {start_date.date()} and {end_date.date()}:\n")
    print(high_precipitation_days)

    # Plot the high precipitation days
    if not high_precipitation_days.empty:
        plt.figure(figsize=(10, 6))
        high_precipitation_days['prcp'].plot(kind='bar', color='blue', alpha=0.7)
        plt.title('Days with Precipitation > 10mm in New York')
        plt.xlabel('Date')
        plt.ylabel('Precipitation (mm)')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.tight_layout()
        plt.show()
    else:
        print("No days with precipitation over 10mm were found.")
# Out:
# ...
# Days with precipitation > 10mm in New York between 2023-01-01 and 2023-12-31:
#
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2023-01-04  13.0  10.2  17.1  14.9   0.0  293.0  10.2   NaN  1010.8   NaN
# 2023-01-12   6.4   0.4  10.8  12.0   0.0   62.0  14.3   NaN  1017.1   NaN
# 2023-01-19   4.3   2.4   6.9  23.0   0.0   32.0  12.0   NaN  1012.2   NaN
# 2023-01-23   2.8   0.8   4.5  10.6   0.0  347.0   8.6   NaN  1004.9   NaN
# 2023-01-25   3.1  -2.0  11.0  23.2   0.0   44.0  14.1   NaN  1018.9   NaN
# 2023-03-04   5.9   4.4   8.0  10.8   0.0  359.0  14.9   NaN  1003.0   NaN
# 2023-03-13   4.9   3.3   6.0  14.6   0.0   76.0  22.5   NaN  1012.0   NaN
# 2023-03-25   6.6   6.1   7.8  10.2   0.0   50.0  23.6   NaN  1013.5   NaN
# 2023-04-23  15.0  11.7  19.4  25.1   0.0  358.0   9.0   NaN  1011.6   NaN
# 2023-04-29  10.9   8.9  12.2  32.0   0.0   40.0  24.1   NaN  1012.5   NaN
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt
from datetime import datetime

# Set the location for New York City (latitude, longitude, altitude)
new_york = Point(40.7128, -74.0060, 10)

# Define the date range for all available data
start_date = datetime(2000, 1, 1)  # Adjust the start date as needed
end_date = datetime.now()  # Up to the current date

# Fetch daily data from Meteostat
data = Daily(new_york, start_date, end_date)
data = data.fetch()

# Check if the data is successfully fetched
if data.empty:
    print("No data available for the given date range and location.")
else:
    # Filter days with precipitation over 10 mm
    high_precipitation_days = data[data['prcp'] > 10]

    # Display the results
    print(f"Days with precipitation > 10mm in New York from {start_date.date()} to {end_date.date()}:\n")
    print(high_precipitation_days)

    # Create a line plot for precipitation trends
    plt.figure(figsize=(14, 7))
    data['prcp'].plot(kind='line', color='blue', alpha=0.7, linewidth=1.5)
    plt.title('Precipitation Trends in New York (2000 - Present)')
    plt.xlabel('Date')
    plt.ylabel('Precipitation (mm)')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    # Plot the high precipitation days
    if not high_precipitation_days.empty:
        plt.figure(figsize=(14, 7))
        high_precipitation_days['prcp'].plot(kind='bar', color='red', alpha=0.7)
        plt.title('Days with Precipitation > 10mm in New York')
        plt.xlabel('Date')
        plt.ylabel('Precipitation (mm)')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.tight_layout()
        plt.show()
    else:
        print("No days with precipitation over 10mm were found.")
# Out:
# Days with precipitation > 10mm in New York from 2000-01-01 to 2024-12-11:
#
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2000-01-04  14.4   8.9  20.0  18.0   0.0  207.0  19.1   NaN  1007.7   NaN
# 2000-01-10  11.1   6.7  15.0  22.6   0.0    NaN  18.0   NaN  1006.3   NaN
# 2000-01-25  -2.8  -4.4  -1.1  21.1  51.0   23.0  34.9   NaN   998.1   NaN
# 2000-02-18   0.6  -1.1   1.7  11.7   0.0    NaN  15.5   NaN  1025.9   NaN
# 2000-03-11   5.6   3.9   7.2  25.4   0.0   70.0  20.9   NaN  1018.2   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-08-09  25.3  22.0  27.2  25.2   0.0  174.0  18.4   NaN  1012.5   NaN
# 2024-08-18  24.3  21.7  28.0  13.0   0.0  129.0  11.3   NaN  1010.5   NaN
# 2024-09-28  18.5  16.7  20.0  15.6   0.0   38.0  22.1   NaN  1014.3   NaN
# 2024-11-21   8.6   3.8  12.0  49.7   0.0   18.0  14.0   NaN   999.5   NaN
# 2024-11-28   8.5   5.6  12.2  14.4   0.0  328.0   9.5   NaN  1005.5   NaN
#
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt
from datetime import datetime

# Set the location for New York City (latitude, longitude, altitude)
new_york = Point(40.7128, -74.0060, 10)

# Define the date range for all available data
start_date = datetime(2000, 1, 1)  # Adjust the start date as needed
end_date = datetime.now()  # Up to the current date

# Fetch daily data from Meteostat
data = Daily(new_york, start_date, end_date)
data = data.fetch()

# Check if the data is successfully fetched
if data.empty:
    print("No data available for the given date range and location.")
else:
    # Filter days with precipitation over 10 mm
    high_precipitation_days = data[data['prcp'] > 10]

    # Display the results
    print(f"Days with precipitation > 10mm in New York from {start_date.date()} to {end_date.date()}:\n")
    print(high_precipitation_days)

    # Create a line plot for precipitation trends
    plt.figure(figsize=(14, 7))
    data['prcp'].plot(kind='line', color='blue', alpha=0.7, linewidth=1.5)
    plt.title('Precipitation Trends in New York (2000 - Present)')
    plt.xlabel('Date')
    plt.ylabel('Precipitation (mm)')
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.tight_layout()
    plt.show()

    # Plot the high precipitation days
    if not high_precipitation_days.empty:
        plt.figure(figsize=(14, 7))
        high_precipitation_days['prcp'].plot(kind='bar', color='red', alpha=0.7)
        plt.title('Days with Precipitation > 10mm in New York')
        plt.xlabel('Date')
        plt.ylabel('Precipitation (mm)')
        plt.grid(axis='y', linestyle='--', alpha=0.7)
        plt.tight_layout()
        plt.show()
    else:
        print("No days with precipitation over 10mm were found.")
# Out:
# Days with precipitation > 10mm in New York from 2000-01-01 to 2024-12-11:
#
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2000-01-04  14.4   8.9  20.0  18.0   0.0  207.0  19.1   NaN  1007.7   NaN
# 2000-01-10  11.1   6.7  15.0  22.6   0.0    NaN  18.0   NaN  1006.3   NaN
# 2000-01-25  -2.8  -4.4  -1.1  21.1  51.0   23.0  34.9   NaN   998.1   NaN
# 2000-02-18   0.6  -1.1   1.7  11.7   0.0    NaN  15.5   NaN  1025.9   NaN
# 2000-03-11   5.6   3.9   7.2  25.4   0.0   70.0  20.9   NaN  1018.2   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2024-08-09  25.3  22.0  27.2  25.2   0.0  174.0  18.4   NaN  1012.5   NaN
# 2024-08-18  24.3  21.7  28.0  13.0   0.0  129.0  11.3   NaN  1010.5   NaN
# 2024-09-28  18.5  16.7  20.0  15.6   0.0   38.0  22.1   NaN  1014.3   NaN
# 2024-11-21   8.6   3.8  12.0  49.7   0.0   18.0  14.0   NaN   999.5   NaN
# 2024-11-28   8.5   5.6  12.2  14.4   0.0  328.0   9.5   NaN  1005.5   NaN
#
# ...

# %%
import pandas as pd
from meteostat import Daily, Point
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Definiere den Ort für Hamburg
hamburg = Point(53.5511, 9.9937)

# Definiere den Zeitraum von 1950 bis heute
start = pd.to_datetime('1950-01-01')
end = pd.to_datetime('today')

# Lese die täglichen Daten für Hamburg
data = Daily(hamburg, start, end)
data = data.fetch()

# Überprüfe, ob Daten verfügbar sind
if data.empty:
    print("Keine Daten für den angegebenen Zeitraum verfügbar.")
else:
    # Finde Tage mit mehr als 10 mm Niederschlag
    data['heavy_rain'] = data['prcp'] > 10

    # Zähle die Anzahl der Tage pro Jahr
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Berechne die prozentuale jährliche Änderung
    percentage_change = heavy_rain_days_per_year.pct_change() * 100

    # Rollende Mittelwerte der prozentualen Änderungen
    percentage_change_ma = percentage_change.rolling(window=5).mean()
    percentage_change_ema = percentage_change.ewm(span=5).mean()
    weights = np.arange(1, 6)
    percentage_change_weighted = percentage_change.rolling(window=5).apply(
        lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
    )

    # Berechne das Mean Squared Error (MSE) für die Methoden
    mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
    mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
    mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])

    print(f'Mean Squared Error (MSE) für 5-Jahre gleitender Durchschnitt (prozentual): {mse_ma:.2f}')
    print(f'Mean Squared Error (MSE) für den exponentiellen gleitenden Durchschnitt (prozentual): {mse_ema:.2f}')
    print(f'Mean Squared Error (MSE) für den gewichteten Durchschnitt (prozentual): {mse_weighted:.2f}')

    # Vorbereitung der Daten für lineare Regression
    years = heavy_rain_days_per_year.index.year.values[1:].reshape(-1, 1) # Überspringe das erste Jahr wegen pct_change()
    values = percentage_change.values[1:]  # Überspringe den ersten Wert (NaN von pct_change())

    # Lineares Regressionsmodell erstellen und anpassen
    model = LinearRegression()
    model.fit(years, values)

    # Vorhersagen für die Regression
    trend_line = model.predict(years)

    # Berechne das Mean Squared Error (MSE) für das lineare Regressionsmodell
    mse_regression = mean_squared_error(values, trend_line)
    print(f'Mean Squared Error (MSE) für die lineare Regression (prozentual): {mse_regression:.2f}')

    # Plot der prozentualen Änderung der schweren Regentage pro Jahr mit Trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change[1:], marker='o', linestyle='-',
             label='Prozentuale Änderung der Anzahl Tage >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ma[1:], linestyle='--',
             label='5-Jahre gleitender Durchschnitt (SMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ema[1:], linestyle='-.',
             label='Exponentieller gleitender Durchschnitt (EMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_weighted[1:], linestyle=':',
             label='Gewichteter Durchschnitt')
    plt.plot(heavy_rain_days_per_year.index.year[1:], trend_line, linestyle='-', color='red',
             label='Lineare Regression')
    plt.title('Prozentuale Änderung der Tage mit >10 mm Regen in Hamburg pro Jahr (1950 bis heute)')
    plt.xlabel('Jahr')
    plt.ylabel('Prozentuale Änderung (%)')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Mean Squared Error (MSE) für 5-Jahre gleitender Durchschnitt (prozentual): 2707.39
# Mean Squared Error (MSE) für den exponentiellen gleitenden Durchschnitt (prozentual): 2000.42
# Mean Squared Error (MSE) für den gewichteten Durchschnitt (prozentual): 2168.01
# Mean Squared Error (MSE) für die lineare Regression (prozentual): 3528.64
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Set the location for New York City (latitude, longitude, altitude)
new_york = Point(40.7128, -74.0060, 10)

# Define the date range for all available data
start_date = pd.to_datetime('1950-01-01')
end_date = pd.to_datetime('today')

# Fetch daily data from Meteostat
data = Daily(new_york, start_date, end_date)
data = data.fetch()

# Check if the data is successfully fetched
if data.empty:
    print("No data available for the given date range and location.")
else:
    # Identify days with more than 10 mm precipitation
    data['heavy_rain'] = data['prcp'] > 10

    # Count the number of heavy rain days per year
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Calculate the percentage annual change
    percentage_change = heavy_rain_days_per_year.pct_change() * 100

    # Rolling averages for percentage changes
    percentage_change_ma = percentage_change.rolling(window=5).mean()
    percentage_change_ema = percentage_change.ewm(span=5).mean()
    weights = np.arange(1, 6)
    percentage_change_weighted = percentage_change.rolling(window=5).apply(
        lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
    )

    # Calculate the Mean Squared Error (MSE) for the methods
    mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
    mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
    mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])

    print(f'Mean Squared Error (MSE) for 5-Year Simple Moving Average: {mse_ma:.2f}')
    print(f'Mean Squared Error (MSE) for Exponential Moving Average: {mse_ema:.2f}')
    print(f'Mean Squared Error (MSE) for Weighted Average: {mse_weighted:.2f}')

    # Prepare data for linear regression
    years = heavy_rain_days_per_year.index.year.values[1:].reshape(-1, 1)  # Skip the first year due to pct_change()
    values = percentage_change.values[1:]  # Skip the first value (NaN from pct_change())

    # Create and fit a linear regression model
    model = LinearRegression()
    model.fit(years, values)

    # Predictions for the regression
    trend_line = model.predict(years)

    # Calculate the Mean Squared Error (MSE) for the linear regression model
    mse_regression = mean_squared_error(values, trend_line)
    print(f'Mean Squared Error (MSE) for Linear Regression: {mse_regression:.2f}')

    # Plot percentage changes of heavy rain days per year with trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change[1:], marker='o', linestyle='-',
             label='Percentage Change of Days >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ma[1:], linestyle='--',
             label='5-Year Simple Moving Average (SMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ema[1:], linestyle='-.',
             label='Exponential Moving Average (EMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_weighted[1:], linestyle=':',
             label='Weighted Average')
    plt.plot(heavy_rain_days_per_year.index.year[1:], trend_line, linestyle='-', color='red',
             label='Linear Regression')
    plt.title('Percentage Change of Days with >10 mm Rain in New York per Year (1950 - Present)')
    plt.xlabel('Year')
    plt.ylabel('Percentage Change (%)')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Mean Squared Error (MSE) for 5-Year Simple Moving Average: 565.95
# Mean Squared Error (MSE) for Exponential Moving Average: 408.00
# Mean Squared Error (MSE) for Weighted Average: 443.88
# Mean Squared Error (MSE) for Linear Regression: 654.23
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Define locations for multiple cities
cities = {
    "New York": Point(40.7128, -74.0060, 10),
    "Moscow": Point(55.7558, 37.6173, 156),
    "Buenos Aires": Point(-34.6037, -58.3816, 25),
    "Brasilia": Point(-15.8267, -47.9218, 1172),
    "Tokyo": Point(35.6895, 139.6917, 40),
    "Cape Town": Point(-33.9249, 18.4241, 42)
}

# Define the date range for all available data
start_date = pd.to_datetime('1950-01-01')
end_date = pd.to_datetime('today')

# Iterate through each city and perform analysis
for city_name, location in cities.items():
    print(f"\nAnalyzing data for {city_name}...")

    # Fetch daily data from Meteostat
    data = Daily(location, start_date, end_date)
    data = data.fetch()

    # Check if the data is successfully fetched
    if data.empty:
        print(f"No data available for {city_name} in the given date range.")
        continue

    # Identify days with more than 10 mm precipitation
    data['heavy_rain'] = data['prcp'] > 10

    # Count the number of heavy rain days per year
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Calculate the percentage annual change
    percentage_change = heavy_rain_days_per_year.pct_change() * 100

    # Rolling averages for percentage changes
    percentage_change_ma = percentage_change.rolling(window=5).mean()
    percentage_change_ema = percentage_change.ewm(span=5).mean()
    weights = np.arange(1, 6)
    percentage_change_weighted = percentage_change.rolling(window=5).apply(
        lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
    )

    # Calculate the Mean Squared Error (MSE) for the methods
    mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
    mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
    mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])

    print(f'Mean Squared Error (MSE) for 5-Year Simple Moving Average: {mse_ma:.2f}')
    print(f'Mean Squared Error (MSE) for Exponential Moving Average: {mse_ema:.2f}')
    print(f'Mean Squared Error (MSE) for Weighted Average: {mse_weighted:.2f}')

    # Prepare data for linear regression
    years = heavy_rain_days_per_year.index.year.values[1:].reshape(-1, 1)  # Skip the first year due to pct_change()
    values = percentage_change.values[1:]  # Skip the first value (NaN from pct_change())

    # Create and fit a linear regression model
    model = LinearRegression()
    model.fit(years, values)

    # Predictions for the regression
    trend_line = model.predict(years)

    # Calculate the Mean Squared Error (MSE) for the linear regression model
    mse_regression = mean_squared_error(values, trend_line)
    print(f'Mean Squared Error (MSE) for Linear Regression: {mse_regression:.2f}')

    # Plot percentage changes of heavy rain days per year with trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change[1:], marker='o', linestyle='-',
             label='Percentage Change of Days >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ma[1:], linestyle='--',
             label='5-Year Simple Moving Average (SMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ema[1:], linestyle='-.',
             label='Exponential Moving Average (EMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_weighted[1:], linestyle=':',
             label='Weighted Average')
    plt.plot(heavy_rain_days_per_year.index.year[1:], trend_line, linestyle='-', color='red',
             label='Linear Regression')
    plt.title(f'Percentage Change of Days with >10 mm Rain in {city_name} per Year (1950 - Present)')
    plt.xlabel('Year')
    plt.ylabel('Percentage Change (%)')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Analyzing data for New York...
# Mean Squared Error (MSE) for 5-Year Simple Moving Average: 565.95
# Mean Squared Error (MSE) for Exponential Moving Average: 408.00
# Mean Squared Error (MSE) for Weighted Average: 443.88
# Mean Squared Error (MSE) for Linear Regression: 654.23
# ...
# Analyzing data for Moscow...
# Mean Squared Error (MSE) for 5-Year Simple Moving Average: 2183.70
# Mean Squared Error (MSE) for Exponential Moving Average: 1555.09
# Mean Squared Error (MSE) for Weighted Average: 1701.66
# Mean Squared Error (MSE) for Linear Regression: 2575.05
# ...
# Analyzing data for Buenos Aires...
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 53
#      48 percentage_change_weighted = percentage_change.rolling(window=5).apply(
#      49     lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
#      50 )
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Define locations for multiple cities
cities = {
    "New York": Point(40.7128, -74.0060, 10),
    "Moscow": Point(55.7558, 37.6173, 156),
    "Buenos Aires": Point(-34.6037, -58.3816, 25),
    "Brasilia": Point(-15.8267, -47.9218, 1172),
    "Tokyo": Point(35.6895, 139.6917, 40),
    "Cape Town": Point(-33.9249, 18.4241, 42)
}

# Define the date range for all available data
start_date = pd.to_datetime('1950-01-01')
end_date = pd.to_datetime('today')

# Iterate through each city and perform analysis
for city_name, location in cities.items():
    print(f"\nAnalyzing data for {city_name}...")

    # Fetch daily data from Meteostat
    data = Daily(location, start_date, end_date)
    data = data.fetch()

    # Check if the data is successfully fetched
    if data.empty:
        print(f"No data available for {city_name} in the given date range.")
        continue

    # Identify days with more than 10 mm precipitation
    data['heavy_rain'] = data['prcp'] > 10

    # Count the number of heavy rain days per year
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Calculate the percentage annual change
    percentage_change = heavy_rain_days_per_year.pct_change() * 100

    # Rolling averages for percentage changes
    percentage_change_ma = percentage_change.rolling(window=5).mean()
    percentage_change_ema = percentage_change.ewm(span=5).mean()
    weights = np.arange(1, 6)
    percentage_change_weighted = percentage_change.rolling(window=5).apply(
        lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
    )

    # Calculate the Mean Squared Error (MSE) for the methods
    mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
    mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
    mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])

    print(f'Mean Squared Error (MSE) for 5-Year Simple Moving Average: {mse_ma:.2f}')
    print(f'Mean Squared Error (MSE) for Exponential Moving Average: {mse_ema:.2f}')
    print(f'Mean Squared Error (MSE) for Weighted Average: {mse_weighted:.2f}')

    # Prepare data for linear regression
    years = heavy_rain_days_per_year.index.year.values[1:].reshape(-1, 1)  # Skip the first year due to pct_change()
    values = percentage_change.values[1:]  # Skip the first value (NaN from pct_change())

    # Create and fit a linear regression model
    model = LinearRegression()
    model.fit(years, values)

    # Predictions for the regression
    trend_line = model.predict(years)

    # Calculate the Mean Squared Error (MSE) for the linear regression model
    mse_regression = mean_squared_error(values, trend_line)
    print(f'Mean Squared Error (MSE) for Linear Regression: {mse_regression:.2f}')

    # Plot percentage changes of heavy rain days per year with trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change[1:], marker='o', linestyle='-',
             label='Percentage Change of Days >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ma[1:], linestyle='--',
             label='5-Year Simple Moving Average (SMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ema[1:], linestyle='-.',
             label='Exponential Moving Average (EMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_weighted[1:], linestyle=':',
             label='Weighted Average')
    plt.plot(heavy_rain_days_per_year.index.year[1:], trend_line, linestyle='-', color='red',
             label='Linear Regression')
    plt.title(f'Percentage Change of Days with >10 mm Rain in {city_name} per Year (1950 - Present)')
    plt.xlabel('Year')
    plt.ylabel('Percentage Change (%)')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Analyzing data for New York...
# Mean Squared Error (MSE) for 5-Year Simple Moving Average: 565.95
# Mean Squared Error (MSE) for Exponential Moving Average: 408.00
# Mean Squared Error (MSE) for Weighted Average: 443.88
# Mean Squared Error (MSE) for Linear Regression: 654.23
# ...
# Analyzing data for Moscow...
# Mean Squared Error (MSE) for 5-Year Simple Moving Average: 2183.70
# Mean Squared Error (MSE) for Exponential Moving Average: 1555.09
# Mean Squared Error (MSE) for Weighted Average: 1701.66
# Mean Squared Error (MSE) for Linear Regression: 2575.05
# Analyzing data for Buenos Aires...
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 53
#      48 percentage_change_weighted = percentage_change.rolling(window=5).apply(
#      49     lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
#      50 )
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Define location for Buenos Aires
city_name = "Buenos Aires"
location = Point(-34.6037, -58.3816, 25)

# Define the date range for all available data
start_date = pd.to_datetime('1950-01-01')
end_date = pd.to_datetime('today')

print(f"\nAnalyzing data for {city_name}...")

# Fetch daily data from Meteostat
data = Daily(location, start_date, end_date)
data = data.fetch()

# Check if the data is successfully fetched
if data.empty:
    print(f"No data available for {city_name} in the given date range.")
else:
    # Identify days with more than 10 mm precipitation
    data['heavy_rain'] = data['prcp'] > 10

    # Count the number of heavy rain days per year
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Calculate the percentage annual change
    percentage_change = heavy_rain_days_per_year.pct_change() * 100

    # Rolling averages for percentage changes
    percentage_change_ma = percentage_change.rolling(window=5).mean()
    percentage_change_ema = percentage_change.ewm(span=5).mean()
    weights = np.arange(1, 6)
    percentage_change_weighted = percentage_change.rolling(window=5).apply(
        lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
    )

    # Calculate the Mean Squared Error (MSE) for the methods
    mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
    mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
    mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])

    print(f'Mean Squared Error (MSE) for 5-Year Simple Moving Average: {mse_ma:.2f}')
    print(f'Mean Squared Error (MSE) for Exponential Moving Average: {mse_ema:.2f}')
    print(f'Mean Squared Error (MSE) for Weighted Average: {mse_weighted:.2f}')

    # Prepare data for linear regression
    years = heavy_rain_days_per_year.index.year.values[1:].reshape(-1, 1)  # Skip the first year due to pct_change()
    values = percentage_change.values[1:]  # Skip the first value (NaN from pct_change())

    # Create and fit a linear regression model
    model = LinearRegression()
    model.fit(years, values)

    # Predictions for the regression
    trend_line = model.predict(years)

    # Calculate the Mean Squared Error (MSE) for the linear regression model
    mse_regression = mean_squared_error(values, trend_line)
    print(f'Mean Squared Error (MSE) for Linear Regression: {mse_regression:.2f}')

    # Plot percentage changes of heavy rain days per year with trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change[1:], marker='o', linestyle='-',
             label='Percentage Change of Days >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ma[1:], linestyle='--',
             label='5-Year Simple Moving Average (SMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ema[1:], linestyle='-.',
             label='Exponential Moving Average (EMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_weighted[1:], linestyle=':',
             label='Weighted Average')
    plt.plot(heavy_rain_days_per_year.index.year[1:], trend_line, linestyle='-', color='red',
             label='Linear Regression')
    plt.title(f'Percentage Change of Days with >10 mm Rain in {city_name} per Year (1950 - Present)')
    plt.xlabel('Year')
    plt.ylabel('Percentage Change (%)')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Analyzing data for Buenos Aires...
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 44
#      39 percentage_change_weighted = percentage_change.rolling(window=5).apply(
#      40     lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
#      41 )
#      43 # Calculate the Mean Squared Error (MSE) for the methods
# ---> 44 mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
#      45 mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
#      46 mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])
#
# File ~/Desktop/Extremwetter/wetter/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Define location for Buenos Aires
city_name = "Buenos Aires"
location = Point(-34.6037, -58.3816, 25)

# Define the date range for all available data
start_date = pd.to_datetime('1950-01-01')
end_date = pd.to_datetime('today')

print(f"\nAnalyzing data for {city_name}...")

# Fetch daily data from Meteostat
data = Daily(location, start_date, end_date)
data = data.fetch()

# Check if the data is successfully fetched
if data.empty:
    print(f"No data available for {city_name} in the given date range.")
else:
    # Identify days with more than 10 mm precipitation
    data['heavy_rain'] = data['prcp'] > 10

    # Count the number of heavy rain days per year
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Calculate the percentage annual change
    percentage_change = heavy_rain_days_per_year.pct_change() * 100

    # Fill NaN values with 0 for safe calculations
    percentage_change = percentage_change.fillna(0)

    # Rolling averages for percentage changes
    percentage_change_ma = percentage_change.rolling(window=5).mean()
    percentage_change_ema = percentage_change.ewm(span=5).mean()
    weights = np.arange(1, 6)
    percentage_change_weighted = percentage_change.rolling(window=5).apply(
        lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
    )

    # Fill NaN values for rolling methods
    percentage_change_ma = percentage_change_ma.fillna(0)
    percentage_change_ema = percentage_change_ema.fillna(0)
    percentage_change_weighted = percentage_change_weighted.fillna(0)

    # Calculate the Mean Squared Error (MSE) for the methods
    mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
    mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
    mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])

    print(f'Mean Squared Error (MSE) for 5-Year Simple Moving Average: {mse_ma:.2f}')
    print(f'Mean Squared Error (MSE) for Exponential Moving Average: {mse_ema:.2f}')
    print(f'Mean Squared Error (MSE) for Weighted Average: {mse_weighted:.2f}')

    # Prepare data for linear regression
    years = heavy_rain_days_per_year.index.year.values[1:].reshape(-1, 1)  # Skip the first year due to pct_change()
    values = percentage_change.values[1:]  # Skip the first value (NaN from pct_change())

    # Create and fit a linear regression model
    model = LinearRegression()
    model.fit(years, values)

    # Predictions for the regression
    trend_line = model.predict(years)

    # Calculate the Mean Squared Error (MSE) for the linear regression model
    mse_regression = mean_squared_error(values, trend_line)
    print(f'Mean Squared Error (MSE) for Linear Regression: {mse_regression:.2f}')

    # Plot percentage changes of heavy rain days per year with trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change[1:], marker='o', linestyle='-',
             label='Percentage Change of Days >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ma[1:], linestyle='--',
             label='5-Year Simple Moving Average (SMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ema[1:], linestyle='-.',
             label='Exponential Moving Average (EMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_weighted[1:], linestyle=':',
             label='Weighted Average')
    plt.plot(heavy_rain_days_per_year.index.year[1:], trend_line, linestyle='-', color='red',
             label='Linear Regression')
    plt.title(f'Percentage Change of Days with >10 mm Rain in {city_name} per Year (1950 - Present)')
    plt.xlabel('Year')
    plt.ylabel('Percentage Change (%)')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Analyzing data for Buenos Aires...
# ...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 52
#      49 percentage_change_weighted = percentage_change_weighted.fillna(0)
#      51 # Calculate the Mean Squared Error (MSE) for the methods
# ---> 52 mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
#      53 mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
#      54 mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])
#
# File ~/Desktop/Extremwetter/wetter/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
# ...

# %%
import pandas as pd
from meteostat import Point, Daily
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
import numpy as np

# Define location for Buenos Aires
city_name = "Buenos Aires"
location = Point(-34.6037, -58.3816, 25)

# Define the date range for all available data
start_date = pd.to_datetime('1950-01-01')
end_date = pd.to_datetime('today')

print(f"\nAnalyzing data for {city_name}...")

# Fetch daily data from Meteostat
data = Daily(location, start_date, end_date)
data = data.fetch()

# Check if the data is successfully fetched
if data.empty:
    print(f"No data available for {city_name} in the given date range.")
else:
    # Identify days with more than 10 mm precipitation
    data['heavy_rain'] = data['prcp'] > 10

    # Count the number of heavy rain days per year
    heavy_rain_days_per_year = data.resample('Y').sum()['heavy_rain']

    # Calculate the percentage annual change
    percentage_change = heavy_rain_days_per_year.pct_change() * 100

    # Replace NaN or infinite values with 0 for safe calculations
    percentage_change = percentage_change.replace([np.inf, -np.inf], np.nan).fillna(0)

    # Rolling averages for percentage changes
    percentage_change_ma = percentage_change.rolling(window=5).mean()
    percentage_change_ema = percentage_change.ewm(span=5).mean()
    weights = np.arange(1, 6)
    percentage_change_weighted = percentage_change.rolling(window=5).apply(
        lambda x: np.dot(x, weights[:len(x)]) / weights[:len(x)].sum(), raw=True
    )

    # Replace NaN or infinite values for rolling methods
    percentage_change_ma = percentage_change_ma.replace([np.inf, -np.inf], np.nan).fillna(0)
    percentage_change_ema = percentage_change_ema.replace([np.inf, -np.inf], np.nan).fillna(0)
    percentage_change_weighted = percentage_change_weighted.replace([np.inf, -np.inf], np.nan).fillna(0)

    # Calculate the Mean Squared Error (MSE) for the methods
    mse_ma = mean_squared_error(percentage_change[5:], percentage_change_ma[5:])
    mse_ema = mean_squared_error(percentage_change[5:], percentage_change_ema[5:])
    mse_weighted = mean_squared_error(percentage_change[5:], percentage_change_weighted[5:])

    print(f'Mean Squared Error (MSE) for 5-Year Simple Moving Average: {mse_ma:.2f}')
    print(f'Mean Squared Error (MSE) for Exponential Moving Average: {mse_ema:.2f}')
    print(f'Mean Squared Error (MSE) for Weighted Average: {mse_weighted:.2f}')

    # Prepare data for linear regression
    years = heavy_rain_days_per_year.index.year.values[1:].reshape(-1, 1)  # Skip the first year due to pct_change()
    values = percentage_change.values[1:]  # Skip the first value (NaN from pct_change())

    # Create and fit a linear regression model
    model = LinearRegression()
    model.fit(years, values)

    # Predictions for the regression
    trend_line = model.predict(years)

    # Calculate the Mean Squared Error (MSE) for the linear regression model
    mse_regression = mean_squared_error(values, trend_line)
    print(f'Mean Squared Error (MSE) for Linear Regression: {mse_regression:.2f}')

    # Plot percentage changes of heavy rain days per year with trends
    plt.figure(figsize=(14, 7))
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change[1:], marker='o', linestyle='-',
             label='Percentage Change of Days >10 mm')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ma[1:], linestyle='--',
             label='5-Year Simple Moving Average (SMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_ema[1:], linestyle='-.',
             label='Exponential Moving Average (EMA)')
    plt.plot(heavy_rain_days_per_year.index.year[1:], percentage_change_weighted[1:], linestyle=':',
             label='Weighted Average')
    plt.plot(heavy_rain_days_per_year.index.year[1:], trend_line, linestyle='-', color='red',
             label='Linear Regression')
    plt.title(f'Percentage Change of Days with >10 mm Rain in {city_name} per Year (1950 - Present)')
    plt.xlabel('Year')
    plt.ylabel('Percentage Change (%)')
    plt.legend()
    plt.grid(True)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# Analyzing data for Buenos Aires...
# Mean Squared Error (MSE) for 5-Year Simple Moving Average: 11505.67
# Mean Squared Error (MSE) for Exponential Moving Average: 7645.02
# Mean Squared Error (MSE) for Weighted Average: 8240.59
# Mean Squared Error (MSE) for Linear Regression: 13485.01
# ...
